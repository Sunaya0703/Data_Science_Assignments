# %% [markdown]
# # Assignment 02:- (Set:-01)

# %% [markdown]
# # Que.01  Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x=pd.Series([24.23,25.41,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
plt.figure(figsize=(6,8))
plt.pie(x,labels=name,autopct='%1.0f%%')
plt.show()

# %%
#Box plot to find outliars

sns.boxplot(x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
x.mean()
# Out:
# 33.263333333333335

# %%
x.var()
# Out:
# 287.28028095238096

# %%
x.std()
# Out:
# 16.94934455819401

# %% [markdown]
# # Assignment 02:- (Set:- 02)

# %% [markdown]
# # Que 1

# %%
import pandas as pd
from scipy import stats

# %%
1-stats.norm.cdf(0.625)
# Out:
# 0.26598552904870054

# %% [markdown]
# Que.2

# %%
# A. More employees at the processing center are older than 44 than between 38 and 44.

# p(X>44); Employees older than 44 yrs of age

1-stats.norm.cdf(44,loc=38,scale=6)
# Out:
# 0.15865525393145707

# %%
# p(38

stats.norm.cdf(44,38,6)-stats.norm.cdf(38,38,6)
# Out:
# 0.3413447460685429

# %%
# B. A training program for employees under the age of 30 at the center would be expected to attract about 36 employees.

# P(X<30); Employees under 30 yrs of age

stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %%
# No. of employees attending training program from 400 nos. is N*P(X<30)

400*stats.norm.cdf(30,38,6)
# Out:
# 36.484487890347154

# %% [markdown]
# # Que 3

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# # Que 5

# %%
# Mean profits from two different divisions of a company = Mean1 + Mean2

Mean = 5+7
print('Mean Profit is Rs', Mean*45,'Million')
# Out:
# Mean Profit is Rs 540 Million

# %%
# Variance of profits from two different divisions of a company = SD^2 = SD1^2 + SD2^2

SD = np.sqrt((9)+(16))
print('Standard Deviation is Rs', SD*45, 'Million')
# Out:
# Standard Deviation is Rs 225.0 Million

# %%
# A. Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.

print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %%
# B. Specify the 5th percentile of profit (in Rupees) for the company
# To compute 5th Percentile, we use the formula X=μ + Zσ; wherein from z table, 5 percentile = -1.645

X= 540+((-1.645)*(225))
print('5th percentile of profit (in  Rupees) is',np.round(X,)*82)
# Out:
# 5th percentile of profit (in  Rupees) is 13940.0

# %%
# C. Which of the two divisions has a larger probability of making a loss in a given year?

# Probability of Division 1 making a loss P(X<0)

stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
# Probability of Division 2 making a loss P(X<0)

stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# # Assignment:- 02 (Set:- 03)

# %% [markdown]
# # Que 5(1)

# %%
# Apply One-Sample One-Tail z-test

z_scores=(0.046-0.05)/(np.sqrt((0.05*(1-0.05))/2000))
z_scores
# Out:
# -0.820782681668124

# %% [markdown]
# # Que 5(2)

# %%
# Find Probability assuming null hyposthesis, so as to compare with Type-1 error α = 0.05

p_value=1-stats.norm.cdf(abs(z_scores))
p_value
# Out:
# 0.20588503245107104

# %%
stats.t.ppf(0.954,2000)
# Out:
# 1.6857497236229495

# %% [markdown]
# # Assignment :- 02 (Set:-04)

# %%
x_bar = 45
s_std = 40
mew = 50

t = np.round(stats.t.ppf(0.025, df = 249),2)
t

# t_value = (x_bar - mew)/(sample_std/n**0.5)
# t = 45-50 or z = 55-50 z = +/- 5

# t = 5/(40/n**0.5)
# n = (sample_standard_deviation*tscore)/(sample_mean=population_mean)

n = ((s_std*abs(t)) / (5))**2

print('The Auditors would like to maintain the probability of investigation to 5%, they should sample',np.round(n,),'transactions if they do not want to change the thresholds of 45 to 55')

df= n-1
print(n, df)

np.round(stats.t.interval(alpha = 0.95, df = df, loc = mew, scale = s_std/np.sqrt(n)),)
# Out:
# The Auditors would like to maintain the probability of investigation to 5%, they should sample 248.0 transactions if they do not want to change the thresholds of 45 to 55
# 248.3776 247.3776
# array([45., 55.])
